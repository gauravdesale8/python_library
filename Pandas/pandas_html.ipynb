# %% [markdown]
# Pandas HTML

# %%
import pandas as pd

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/Mobile_country_code")

# %%
type(html)
# Out:
# list

# %%
html
# Out:
# [   MCC  MNC Brand      Operator       Status Bands (MHz)
#  0    1    1  TEST  Test network  Operational         any  \
#  1    1    1  TEST  Test network  Operational         any
#  2  999   99   NaN  Internal use  Operational         any
#  3  999  999   NaN  Internal use  Operational         any
#
#                                References and notes
#  0                                              NaN
#  1                                              NaN
#  2  Internal use in private networks, no roaming[4]
#  3  Internal use in private networks, no roaming[4]  ,
#       Mobile country code                                    Country ISO 3166
#  0                    289                                 A Abkhazia    GE-AB  \
#  1                    412                                Afghanistan       AF
#  2                    276                                    Albania       AL
#  3                    603                                    Algeria       DZ
# ...

# %%
html[0]
# Out:
#    MCC  MNC Brand      Operator       Status Bands (MHz)
# 0    1    1  TEST  Test network  Operational         any  \
# 1    1    1  TEST  Test network  Operational         any
# 2  999   99   NaN  Internal use  Operational         any
# 3  999  999   NaN  Internal use  Operational         any
#
#                               References and notes
# 0                                              NaN
# 1                                              NaN
# 2  Internal use in private networks, no roaming[4]
# 3  Internal use in private networks, no roaming[4]

# %%
html[1]
# Out:
#      Mobile country code                                    Country ISO 3166
# 0                    289                                 A Abkhazia    GE-AB  \
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
type(html[1])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Specific Table from html

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/New_York_City", match = "Month")

# %%
html
# Out:
# [   vteClimate data for New York (Belvedere Castle, Central Park), 1991–2020 normals,[b] extremes 1869–present[c]
#                                                                                                             Month
#  0                                 Record high °F (°C)                                                             \
#  1                                Mean maximum °F (°C)
#  2                                Average high °F (°C)
#  3                                  Daily mean °F (°C)
#  4                                 Average low °F (°C)
#  5                                Mean minimum °F (°C)
#  6                                  Record low °F (°C)
#  7                   Average precipitation inches (mm)
#  8                        Average snowfall inches (cm)
#  9              Average precipitation days (≥ 0.01 in)
#  10                      Average snowy days (≥ 0.1 in)
#  11                      Average relative humidity (%)
# ...

# %%
html[0]
# Out:
#    vteClimate data for New York (Belvedere Castle, Central Park), 1991–2020 normals,[b] extremes 1869–present[c]
#                                                                                                            Month
# 0                                 Record high °F (°C)                                                             \
# 1                                Mean maximum °F (°C)
# 2                                Average high °F (°C)
# 3                                  Daily mean °F (°C)
# 4                                 Average low °F (°C)
# 5                                Mean minimum °F (°C)
# 6                                  Record low °F (°C)
# 7                   Average precipitation inches (mm)
# 8                        Average snowfall inches (cm)
# 9              Average precipitation days (≥ 0.01 in)
# 10                      Average snowy days (≥ 0.1 in)
# 11                      Average relative humidity (%)
# ...

# %%
type(html[0])
# Out:
# pandas.core.frame.DataFrame

# %%
html[0].to_html("demo.html")
