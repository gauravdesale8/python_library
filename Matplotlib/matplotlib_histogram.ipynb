# %% [markdown]
# Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

no = np.random.randint(10,60,20)
print(no)
plt.hist(no)
plt.show()
# Out:
# [38 38 12 42 16 27 20 50 46 42 53 49 26 58 13 47 34 23 52 35]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)

plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,"auto",(0,200), edgecolor="k")
plt.show()
# Out:
# [58 20 54 67 24 33 64 19 59 41 29 25 66 30 58 13 13 58 43 37]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k")
plt.show()
# Out:
# [21 44 69 24 64 60 57 10 57 56 69 64 61 47 21 30 66 27 35 12]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",cumulative=-1)
plt.show()
# Out:
# [15 10 32 60 47 49 62 26 49 24 41 57 10 48 33 12 51 50 60 14]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",cumulative=-1,bottom=10)
plt.show()
# Out:
# [51 58 56 25 30 61 45 37 22 57 27 13 26 33 20 18 34 68 63 13]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",histtype="step")
plt.show()
# Out:
# [34 29 25 18 54 30 53 51 57 32 58 33 28 62 59 48 67 64 18 58]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",histtype="stepfilled")
plt.show()
# Out:
# [31 18 61 64 46 61 21 55 15 13 20 48 66 27 27 47 61 53 24 14]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",histtype="barstacked")
plt.show()
# Out:
# [11 24 55 63 69 24 35 17 41 36 27 32 40 41 42 18 56 20 35 63]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",orientation="horizontal")
plt.show()
# Out:
# [39 61 62 16 37 20 13 27 65 12 57 60 54 65 42 26 45 43 61 15]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",rwidth=0.8)
plt.show()
# Out:
# [58 14 57 23 63 21 21 40 24 66 31 38 50 22 47 14 16 48 21 25]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",log=True)
plt.show()
# Out:
# [61 33 58 53 53 68 14 42 35 49 67 50 52 59 25 51 11 24 51 34]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.hist(day,bins=b, edgecolor="k",label="Python")
plt.legend()
plt.show()
# Out:
# [38 18 49 58 20 34 55 69 56 11 39 25 36 66 69 22 33 45 63 38]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.axvline(35,color="r")

plt.hist(day,bins=b, edgecolor="k")
plt.show()
# Out:
# [18 51 49 27 60 39 63 20 17 20 19 11 31 48 52 45 41 56 62 14]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.axvline(35,color="m",label="line")

plt.hist(day,bins=b, edgecolor="k",label="Python")
plt.legend()
plt.show()
# Out:
# [39 38 60 46 44 62 35 20 46 56 13 33 45 68 57 61 51 16 33 23]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

b = [10,20,30,40,50,60]
day = np.random.randint(10,70,20)
print(day)


plt.title("Histogram")
plt.xlabel("Xpara")
plt.ylabel("ypara")

plt.axvline(35,color="m",label="line")

plt.hist(day,bins=b, edgecolor="k",label="Python")
plt.legend()
plt.grid()
plt.show()
# Out:
# [23 54 54 19 54 51 23 49 30 27 26 52 32 49 65 17 23 23 16 17]
